# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib notebook

# %%
data=np.arange(10)
data
plt.plot(data)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
fig=plt.figure()#生成画布
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
ax1=fig.add_subplot(2,2,1)
ax2=fig.add_subplot(2,2,2)
ax3=fig.add_subplot(2,2,3)

# %%
plt.plot(np.random.randn(50).cumsum(),'b--')

# %%
ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
# Out:
# (array([ 1.,  0.,  2.,  6.,  2.,  6., 16.,  9., 12.,  9.,  9., 11.,  4.,
#          5.,  5.,  1.,  1.,  0.,  0.,  1.]),
#  array([-2.4851564 , -2.21559541, -1.94603442, -1.67647343, -1.40691244,
#         -1.13735144, -0.86779045, -0.59822946, -0.32866847, -0.05910748,
#          0.21045352,  0.48001451,  0.7495755 ,  1.01913649,  1.28869749,
#          1.55825848,  1.82781947,  2.09738046,  2.36694145,  2.63650245,
#          2.90606344]),
#  <BarContainer object of 20 artists>)

# %%
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))#散点图

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0.5,hspace=0.5)#生成子图，wspace控制宽和高的
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
plt.plot(np.random.randn(30).cumsum(),'ko--')

# %%
import pandas as pd

# %%
df=pd.DataFrame(np.random.randn(10,4).cumsum(0),columns=['A','B','C','D'],index=np.arange(0,100,10))
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <Axes: >

# %%
fig,axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <Axes: >

# %%
data.plot.barh(ax=axes[1],color='r',alpha=0.7)
# Out:
# <Axes: >

# %%
df=pd.DataFrame(np.random.rand(6,4),index=['one','two','three','four','fiv','six'],
             columns=pd.Index(['A','B','C','D'],name='G'))

# %%
df.plot.bar(stacked=True,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <Axes: >

# %%
df.plot.barh(stacked=True,alpha=0.5)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">
# <Axes: >
# <Axes: >
